# %%
import pandas as pd

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info()
df.drop(['Surname','Geography'],axis = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  int64
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 1.1+ MB
# ...

# %%
#univariate statistical analysis
df['CreditScore'].mean()
# Out:
# 650.5288

# %%
df['CreditScore'].median()
# Out:
# 652.0

# %%
df['CreditScore'].std()
# Out:
# 96.65329873613035

# %%
df['CreditScore'].value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: CreditScore, Length: 460, dtype: int64

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['CreditScore'],grid=False)

# %%
df.hist(column=['Age'],grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fab8a9ad7d0>]],
#       dtype=object)

# %%
#Multivariate analysis
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore    Gender       Age  \
# RowNumber         1.000000    0.004202     0.005840 -0.018196  0.000783
# CustomerId        0.004202    1.000000     0.005308  0.002641  0.009497
# CreditScore       0.005840    0.005308     1.000000  0.002857 -0.003965
# Gender           -0.018196    0.002641     0.002857  1.000000  0.027544
# Age               0.000783    0.009497    -0.003965  0.027544  1.000000
# Tenure           -0.006495   -0.014883     0.000842 -0.014733 -0.009997
# Balance          -0.009067   -0.012419     0.006268 -0.012087  0.028308
# NumOfProducts     0.007246    0.016972     0.012238  0.021859 -0.030680
# HasCrCard         0.000599   -0.014025    -0.005458 -0.005766 -0.011721
# IsActiveMember    0.012044    0.001665     0.025651 -0.022544  0.085472
# EstimatedSalary  -0.005988    0.015271    -0.001384  0.008112 -0.007201
# Exited           -0.016571   -0.006248    -0.027094  0.106512  0.285323
#
# ...

# %%
sns.heatmap(df.corr())

# %%
#Bivariate analysis
sns.barplot(x='Age',y='CreditScore',data = df)

# %%
sns.boxplot(x="Age", y="CreditScore", data=df,palette='rainbow')

# %%
#Missing values
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#Find outliers and reject
q_low = df["CreditScore"].quantile(0.01)
q_hi  = df["CreditScore"].quantile(0.99)

df_filtered = df[(df["CreditScore"] < q_hi) & (df["CreditScore"] > q_low)]
df_filtered.boxplot(column=['CreditScore'],grid=False)

# %%
#Categorical values - encoding
df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# 9999    1
# Name: Gender, Length: 10000, dtype: int64

# %%
df['Gender'].replace({'Male':0, 'Female':1}, inplace=True)
df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# 9999    1
# Name: Gender, Length: 10000, dtype: int64

# %%
#independent and dependent variable
df["Exited"].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
#independent variables
X = df.iloc[:, :-1].values
print(X)
# Out:
# [[1 15634602 'Hargrave' ... 1 1 101348.88]
#  [2 15647311 'Hill' ... 0 1 112542.58]
#  [3 15619304 'Onio' ... 1 0 113931.57]
#  ...
#  [9998 15584532 'Liu' ... 0 1 42085.58]
#  [9999 15682355 'Sabbatini' ... 1 0 92888.52]
#  [10000 15628319 'Walker' ... 1 0 38190.78]]

# %%
#dependent variables
y = df.iloc[:, -1].values
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (6700, 13) (3300, 13) (6700,) (3300,)
